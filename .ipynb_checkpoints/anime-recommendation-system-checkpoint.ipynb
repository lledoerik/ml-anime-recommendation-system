# %%
import pandas as pd

r_cols = ['user_id', 'anime_id', 'rating']
ratings = pd.read_csv('data/rating.csv', sep=',', encoding='utf-8')

a_cols = ['anime_id', 'name', 'members']
movies = pd.read_csv('data/anime.csv', sep=',', usecols=a_cols, encoding='utf-8')

ratings = pd.merge(movies, ratings)

ratings.head(10000000)
# Out:
#          anime_id                                               name  members  \
# 0           32281                                     Kimi no Na wa.   200630
# 1           32281                                     Kimi no Na wa.   200630
# 2           32281                                     Kimi no Na wa.   200630
# 3           32281                                     Kimi no Na wa.   200630
# 4           32281                                     Kimi no Na wa.   200630
# ...           ...                                                ...      ...
# 7813722      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...      175
# 7813723      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...      175
# 7813724      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...      175
# 7813725     26081                   Yasuji no Pornorama: Yacchimae!!      142
# 7813726     26081                   Yasuji no Pornorama: Yacchimae!!      142
#
#          user_id  rating
# ...
